# %%
# 1. Setup & Imports 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import optuna
from optuna.integration import LightGBMPruningCallback
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.model_selection import StratifiedKFold
import shap


# Advanced Model
import lightgbm as lgb

import os

import warnings
warnings.filterwarnings('ignore', message='.*dask-expr.*')

# %%
# 2. Load Latest Preprocessed Data 

# Find the most recent preprocessed data folder
preprocessed_dir = os.path.join('../..', 'data', 'preprocessed')
latest_folder = sorted([d for d in os.listdir(preprocessed_dir) if os.path.isdir(os.path.join(preprocessed_dir, d))])[-1]
latest_data_path = os.path.join(preprocessed_dir, latest_folder)
print(f"Loading data from the most recent folder: '{latest_data_path}'")

# Load the scaled data sets
X_train = pd.read_csv(os.path.join(latest_data_path, 'X_train_scaled.csv'))
y_train = pd.read_csv(os.path.join(latest_data_path, 'y_train_scaled.csv')).squeeze()
X_test = pd.read_csv(os.path.join(latest_data_path, 'X_test_scaled.csv'))
y_test = pd.read_csv(os.path.join(latest_data_path, 'y_test_scaled.csv')).squeeze()

print(f"\nData loaded successfully. Training with {len(X_train)} samples.")
# Out:
# Loading data from the most recent folder: '../../data/preprocessed/preprocessed_data_20250720_131842'
#
# Data loaded successfully. Training with 1688 samples.

# %%
print("\n\n--- Training Advanced Model: LightGBM Classifier ---")

lgbm_model = lgb.LGBMClassifier(verbosity=-1, 
                                random_state=42, 
                                gpu_device_id=0,
                                gpu_platform_id=0)

param_grid_lgbm = {
    'n_estimators': [300, 350, 400, 450, 500],
    'learning_rate': [0.025, 0.05, 0.075],
    'num_leaves': [20, 30, 40, 50],
    'max_depth': [6, 7, 8, 9],
    'min_child_samples': [10, 20, 30],
    'subsample': [0.8, 0.9],
    'colsample_bytree': [0.8, 0.9],
    'reg_alpha': [0.0, 0.1],
    'reg_lambda': [0.0, 0.1],
    'boosting_type': ['gbdt'],
    'objective': ['multiclass'],
    'num_class': [7]  # Assuming a 7-class classification problem
}

# Use GridSearchCV with 'accuracy' as the scoring metric
grid_lgbm = GridSearchCV(lgbm_model, param_grid_lgbm, cv=5, scoring='accuracy', n_jobs=-1)
grid_lgbm.fit(X_train, y_train)

# Print the best parameters and score
print(f"\nBest parameters for LightGBM: {grid_lgbm.best_params_}")
print(f"Best cross-validated Accuracy: {grid_lgbm.best_score_:.4f}")

# Evaluate on the test set
y_pred_lgbm = grid_lgbm.predict(X_test)
train_accuracy_lgbm = accuracy_score(y_train, grid_lgbm.predict(X_train))
test_accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)

print(f"\nLightGBM Train Accuracy: {train_accuracy_lgbm:.4f}")
print(f"LightGBM Test Accuracy: {test_accuracy_lgbm:.4f}")

print("\nLightGBM Test Set Classification Report:")
print(classification_report(y_test, y_pred_lgbm))

# Confusion Matrix
cm = confusion_matrix(y_test.values, y_pred_lgbm)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[f'Class {i}' for i in range(len(cm))],
            yticklabels=[f'Class {i}' for i in range(len(cm))])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
def objective(trial):
    """Optuna objective function for LightGBM"""
    
    # Suggest hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, 5),
        'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.1, 0.01),
        'num_leaves': trial.suggest_int('num_leaves', 10, 100, 5),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100, 5),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0, 0.01),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0, 0.01),
        'reg_alpha': [0.0],
        'reg_lambda': [0.0],
        'verbosity': -1,
        'random_state': 42,
        'gpu_device_id': 0,
        'gpu_platform_id': 0,
        'objective': 'multiclass',
        'num_class': 7
    }
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []
    
    for train_idx, val_idx in cv.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx] 
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        # Create model with pruning callback
        model = lgb.LGBMClassifier(**params)
        
        # Fit with early stopping and pruning
        model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)]
        )
        
        # Get validation score
        val_pred = model.predict(X_val)
        val_score = accuracy_score(y_val, val_pred)
        scores.append(val_score)
    
    return np.mean(scores)

# Create study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=2000)  # Much faster than GridSearch

print(f"Best parameters: {study.best_params}")
print(f"Best accuracy: {study.best_value:.4f}")

# %%
def evaluate_top_models(study, X_train, y_train, X_test, y_test, top_n=5):
    """Train and evaluate top N models on test set"""
    
    trials = sorted(study.trials, key=lambda t: t.value, reverse=True)
    top_trials = trials[:top_n]
    
    results = []
    
    print(f"\n🧪 EVALUATING TOP {top_n} MODELS ON TEST SET:")
    print("="*80)
    
    for rank, trial in enumerate(top_trials, 1):
        # Get parameters
        params = trial.params.copy()
        params.update({
            'verbosity': -1,
            'random_state': 42,
            'objective': 'multiclass',
            'num_class': 7,
            'gpu_device_id': 0,
            'gpu_platform_id': 0,
        })
        
        # Train model
        model = lgb.LGBMClassifier(**params)
        model.fit(X_train, y_train)
        
        # Evaluate
        train_pred = model.predict(X_train)
        test_pred = model.predict(X_test)
        
        train_acc = accuracy_score(y_train, train_pred)
        test_acc = accuracy_score(y_test, test_pred)
        
        print(f"\n#{rank} - CV: {trial.value:.4f} | Train: {train_acc:.4f} | Test: {test_acc:.4f}")
        print(f"   Key params: {params}")
        
        results.append({
            'Rank': rank,
            'CV_Accuracy': trial.value,
            'Train_Accuracy': train_acc,
            'Test_Accuracy': test_acc,
            'Params': params
        })
    
    return results

# Evaluate top models
top_results = evaluate_top_models(study, X_train, y_train, X_test, y_test, top_n=200)

# Create comparison DataFrame
comparison_df = pd.DataFrame([
    {
        'Rank': r['Rank'],
        'CV_Accuracy': r['CV_Accuracy'],
        'Train_Accuracy': r['Train_Accuracy'], 
        'Test_Accuracy': r['Test_Accuracy'],
        'Overfitting': r['Train_Accuracy'] - r['Test_Accuracy']
    }
    for r in top_results
])

print("\n📈 MODEL COMPARISON:")
display(comparison_df.round(4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 49
#      46     return results
#      48 # Evaluate top models
# ---> 49 top_results = evaluate_top_models(study, X_train, y_train, X_test, y_test, top_n=200)
#      51 # Create comparison DataFrame
#      52 comparison_df = pd.DataFrame([
#      53     {
#      54         'Rank': r['Rank'],
#    (...)     60     for r in top_results
#      61 ])
#
# NameError: name 'study' is not defined

# %%
lgbm_model = lgb.LGBMClassifier(verbosity=-1, 
                                random_state=42, 
                                gpu_device_id=0,
                                gpu_platform_id=0)

param_grid_lgbm = {
    'n_estimators': [815],
    'learning_rate': [0.18502652149436183],
    'num_leaves': [70],
    'max_depth': [5],
    'min_child_samples': [45],
    'subsample': [0.6633868530528707],
    'colsample_bytree': [0.8785984716278369],
    'reg_alpha': [0.00011286229652520546],
    'reg_lambda': [0.01701653807848482],
    'boosting_type': ['gbdt'],
    'objective': ['multiclass'],
    'num_class': [7]  # Assuming a 7-class classification problem
}

# Use GridSearchCV with 'accuracy' as the scoring metric
grid_lgbm = GridSearchCV(lgbm_model, param_grid_lgbm, cv=5, scoring='accuracy', n_jobs=-1)
grid_lgbm.fit(X_train, y_train)

# Print the best parameters and score
print(f"\nBest parameters for LightGBM: {grid_lgbm.best_params_}")
print(f"Best cross-validated Accuracy: {grid_lgbm.best_score_:.4f}")

# Evaluate on the test set
y_pred_lgbm = grid_lgbm.predict(X_test)
train_accuracy_lgbm = accuracy_score(y_train, grid_lgbm.predict(X_train))
test_accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)

print(f"\nLightGBM Train Accuracy: {train_accuracy_lgbm:.4f}")
print(f"LightGBM Test Accuracy: {test_accuracy_lgbm:.4f}")

print("\nLightGBM Test Set Classification Report:")
print(classification_report(y_test, y_pred_lgbm))

# Confusion Matrix
cm = confusion_matrix(y_test.values, y_pred_lgbm)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[f'Class {i}' for i in range(len(cm))],
            yticklabels=[f'Class {i}' for i in range(len(cm))])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Best parameters for LightGBM: {'boosting_type': 'gbdt', 'colsample_bytree': 0.8785984716278369, 'learning_rate': 0.18502652149436183, 'max_depth': 5, 'min_child_samples': 45, 'n_estimators': 815, 'num_class': 7, 'num_leaves': 70, 'objective': 'multiclass', 'reg_alpha': 0.00011286229652520546, 'reg_lambda': 0.01701653807848482, 'subsample': 0.6633868530528707}
# Best cross-validated Accuracy: 0.9686
#
# LightGBM Train Accuracy: 1.0000
# LightGBM Test Accuracy: 0.9740
#
# LightGBM Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        54
#            1       0.89      0.97      0.93        58
#            2       1.00      0.99      0.99        70
#            3       0.98      1.00      0.99        60
#            4       1.00      0.98      0.99        65
#            5       0.96      0.93      0.95        58
#            6       1.00      1.00      1.00        58
#
#     accuracy                           0.97       423
#    macro avg       0.97      0.97      0.97       423
# weighted avg       0.98      0.97      0.97       423

# %%
best_model_lgb = grid_lgbm.best_estimator_

# Get feature importance
feature_importance = best_model_lgb.feature_importances_

# Get feature names
feature_names = X_train.columns.tolist()

# Create DataFrame 
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.show()

# %%
# Get feature importance
feature_importance = grid_lgbm.best_estimator_.feature_importances_

# Get feature names
feature_names = X_train.columns.tolist()

# Create DataFrame 
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('LightGBM Feature Importance')
plt.show()

# %%
# Initialize SHAP explainer with your best model
best_model_lgb = grid_lgbm.best_estimator_

# Create SHAP explainer for tree-based models
explainer = shap.TreeExplainer(best_model_lgb)

# Calculate SHAP values for test set (or subset for speed)
# Use a sample if your dataset is large
sample_size = min(1000, len(X_test))  # Use max 1000 samples for visualization
X_test_sample = X_test.sample(n=sample_size, random_state=42)

print(f"Calculating SHAP values for {len(X_test_sample)} samples...")
shap_values = explainer.shap_values(X_test_sample)

print("SHAP values calculated successfully!")
print(f"SHAP values shape: {len(shap_values)} classes x {shap_values[0].shape}")
# Out:
# Calculating SHAP values for 423 samples...
# SHAP values calculated successfully!
# SHAP values shape: 423 classes x (21, 7)

# %%
# 1. Overall feature importance across all classes
shap.summary_plot(shap_values, X_test_sample, plot_type="bar", 
                 class_names=[f'Obesity Level {i}' for i in range(7)])

# %%
model = grid_lgbm.best_estimator_

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X_test_sample)

print(f"SHAP values shape: {shap_values.shape}")
print(f"Shape interpretation: ({shap_values.shape[0]} samples, {shap_values.shape[1]} features, {shap_values.shape[2]} classes)")

sample_id = 0

# Get the predicted class for the first sample to make it meaningful
sample_0_data = X_test_sample.iloc[[sample_id]]
predicted_class = model.predict(sample_0_data)[sample_id]
prediction_proba = model.predict_proba(sample_0_data)[sample_id]

print(f"\nSample 0 prediction: Class {predicted_class}")
print(f"Class probabilities: {prediction_proba}")

# visualize the first prediction's explanation for the predicted class
shap.plots.waterfall(shap_values[0, :, predicted_class])
# Out:
# SHAP values shape: (423, 21, 7)
# Shape interpretation: (423 samples, 21 features, 7 classes)
#
# Sample 0 prediction: Class 3
# Class probabilities: [1.04792487e-10 9.45355491e-13 1.52379576e-06 9.99998458e-01
#  7.91163818e-09 2.69333824e-10 9.70378847e-09]

# %%
selected_columns = ['Weight', 
                    'Height', 
                    'Gender_Male', 
                    'FCVC',
                    'TUE',
                    'CH2O',
                    'NCP',
                    'FAF',
                    'CAEC',
                    'CALC',
                    'family_history_with_overweight',
                    'FAVC']
X_train_selected = X_train[selected_columns].copy()
X_test_selected = X_test[selected_columns].copy()

# %%
lgbm_model = lgb.LGBMClassifier(verbosity=-1, 
                                random_state=42, 
                                gpu_device_id=0,
                                gpu_platform_id=0)

param_grid_lgbm = {
    'n_estimators': [815],
    'learning_rate': [0.18502652149436183],
    'num_leaves': [70],
    'max_depth': [5],
    'min_child_samples': [45],
    'subsample': [0.6633868530528707],
    'colsample_bytree': [0.8785984716278369],
    'reg_alpha': [0.00011286229652520546],
    'reg_lambda': [0.01701653807848482],
    'boosting_type': ['gbdt'],
    'objective': ['multiclass'],
    'num_class': [7]  # Assuming a 7-class classification problem
}

# Use GridSearchCV with 'accuracy' as the scoring metric
grid_lgbm = GridSearchCV(lgbm_model, param_grid_lgbm, cv=5, scoring='accuracy', n_jobs=-1)
grid_lgbm.fit(X_train_selected, y_train)

# Print the best parameters and score
print(f"\nBest parameters for LightGBM: {grid_lgbm.best_params_}")
print(f"Best cross-validated Accuracy: {grid_lgbm.best_score_:.4f}")

# Evaluate on the test set
y_pred_lgbm = grid_lgbm.predict(X_test_selected)
train_accuracy_lgbm = accuracy_score(y_train, grid_lgbm.predict(X_train_selected))
test_accuracy_lgbm = accuracy_score(y_test, y_pred_lgbm)

print(f"\nLightGBM Train Accuracy: {train_accuracy_lgbm:.4f}")
print(f"LightGBM Test Accuracy: {test_accuracy_lgbm:.4f}")

print("\nLightGBM Test Set Classification Report:")
print(classification_report(y_test, y_pred_lgbm))

# Confusion Matrix
cm = confusion_matrix(y_test.values, y_pred_lgbm)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=[f'Class {i}' for i in range(len(cm))],
            yticklabels=[f'Class {i}' for i in range(len(cm))])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Best parameters for LightGBM: {'boosting_type': 'gbdt', 'colsample_bytree': 0.8785984716278369, 'learning_rate': 0.18502652149436183, 'max_depth': 5, 'min_child_samples': 45, 'n_estimators': 815, 'num_class': 7, 'num_leaves': 70, 'objective': 'multiclass', 'reg_alpha': 0.00011286229652520546, 'reg_lambda': 0.01701653807848482, 'subsample': 0.6633868530528707}
# Best cross-validated Accuracy: 0.9674
#
# LightGBM Train Accuracy: 1.0000
# LightGBM Test Accuracy: 0.9645
#
# LightGBM Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        54
#            1       0.86      0.97      0.91        58
#            2       1.00      0.97      0.99        70
#            3       0.98      1.00      0.99        60
#            4       1.00      0.98      0.99        65
#            5       0.96      0.88      0.92        58
#            6       0.97      1.00      0.98        58
#
#     accuracy                           0.96       423
#    macro avg       0.96      0.96      0.96       423
# weighted avg       0.97      0.96      0.96       423

# %%
def objective2(trial):
    """Optuna objective function for LightGBM"""
    
    # Suggest hyperparameters
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 170, 170, step=1),
        'learning_rate': trial.suggest_float('learning_rate', 0.079, 0.079, step=0.001),
        'num_leaves': trial.suggest_int('num_leaves', 5, 5, step=1),
        'max_depth': trial.suggest_int('max_depth', 6, 6, step=1),
        'min_child_samples': trial.suggest_int('min_child_samples', 255, 255, step=1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.36, 0.5, step=0.005),
        # 'reg_lambda': trial.suggest_float('reg_lambda', 0, 0.05, step=0.005),
        'subsample': trial.suggest_float('subsample', 0.65, 0.85, step=0.01),
        # 'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 0.9, step=0.01),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 1),
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt']),
        'verbosity': -1,
        'random_state': 42,
        'gpu_device_id': 0,
        'gpu_platform_id': 0,
        'objective': 'multiclass',
        'num_class': 7
    }
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []
    
    for train_idx, val_idx in cv.split(X_train_selected, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx] 
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        # Create model with pruning callback
        model = lgb.LGBMClassifier(**params)
        
        # Fit with early stopping and pruning
        model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)]
        )
        
        # Get validation score
        val_pred = model.predict(X_val)
        val_score = accuracy_score(y_val, val_pred)
        scores.append(val_score)
    
    return np.mean(scores)

# Create study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective2, n_trials=200)  # Much faster than GridSearch

print(f"Best parameters: {study.best_params}")
print(f"Best accuracy: {study.best_value:.4f}")
# Out:
# [I 2025-07-24 00:20:14,234] A new study created in memory with name: no-name-2b5c1da9-b7e4-4ce4-a560-11d82f1948d7
# [I 2025-07-24 00:20:14,630] Trial 0 finished with value: 0.8992888873281478 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.49, 'subsample': 0.68, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 0.8992888873281478.
# [I 2025-07-24 00:20:15,020] Trial 1 finished with value: 0.9105437817147474 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.73, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.9105437817147474.
# [I 2025-07-24 00:20:15,393] Trial 2 finished with value: 0.9058065422365809 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.5, 'subsample': 0.7000000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 1 with value: 0.9105437817147474.
# [I 2025-07-24 00:20:15,834] Trial 3 finished with value: 0.9342352466068513 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:16,215] Trial 4 finished with value: 0.9277246150334486 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:16,602] Trial 5 finished with value: 0.9283145751760223 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:16,960] Trial 6 finished with value: 0.912320685477499 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.42, 'subsample': 0.73, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:17,302] Trial 7 finished with value: 0.8915842887995364 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.42, 'subsample': 0.66, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:17,657] Trial 8 finished with value: 0.8939599318736503 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45999999999999996, 'subsample': 0.67, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:18,033] Trial 9 finished with value: 0.9223851245764051 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.445, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:18,432] Trial 10 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.9342352466068513.
# [I 2025-07-24 00:20:18,845] Trial 11 finished with value: 0.9348287184169404 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:19,250] Trial 12 finished with value: 0.9212052042912576 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.77, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:19,637] Trial 13 finished with value: 0.9318666268677681 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:20,021] Trial 14 finished with value: 0.9289062911523537 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:20,401] Trial 15 finished with value: 0.9223886362439204 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.77, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:20,790] Trial 16 finished with value: 0.9265341597457553 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:21,186] Trial 17 finished with value: 0.93364353063052 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.415, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:21,572] Trial 18 finished with value: 0.9212069601250154 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:21,956] Trial 19 finished with value: 0.9194283005285058 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:22,339] Trial 20 finished with value: 0.9182413569083281 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.40499999999999997, 'subsample': 0.76, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:22,739] Trial 21 finished with value: 0.93364353063052 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.415, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:23,137] Trial 22 finished with value: 0.9312749108914368 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:23,593] Trial 23 finished with value: 0.9342352466068513 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:23,978] Trial 24 finished with value: 0.9253559952943655 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:24,413] Trial 25 finished with value: 0.9312749108914368 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:24,866] Trial 26 finished with value: 0.9318683827015258 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.445, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:25,259] Trial 27 finished with value: 0.9247590118167611 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.43, 'subsample': 0.8, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:25,661] Trial 28 finished with value: 0.9294962512949274 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.48, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:26,038] Trial 29 finished with value: 0.9117342370024406 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45499999999999996, 'subsample': 0.74, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:26,440] Trial 30 finished with value: 0.9123259529787721 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.71, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:26,881] Trial 31 finished with value: 0.9342352466068513 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:27,318] Trial 32 finished with value: 0.9318666268677681 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.40499999999999997, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:27,729] Trial 33 finished with value: 0.9289045353185961 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.425, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:28,131] Trial 34 finished with value: 0.9318666268677681 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.46499999999999997, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:28,523] Trial 35 finished with value: 0.9259406879356662 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.485, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:28,919] Trial 36 finished with value: 0.9336452864642775 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:29,320] Trial 37 finished with value: 0.9324600986778572 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:29,679] Trial 38 finished with value: 0.9022509788773199 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.6900000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:30,069] Trial 39 finished with value: 0.9318683827015258 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.425, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:30,456] Trial 40 finished with value: 0.9247625234842765 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.8, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:30,895] Trial 41 finished with value: 0.9300879672712586 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.415, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:31,338] Trial 42 finished with value: 0.9336452864642775 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:31,776] Trial 43 finished with value: 0.9336417747967622 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:32,184] Trial 44 finished with value: 0.9259477112706967 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:32,578] Trial 45 finished with value: 0.9277211033659333 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:33,034] Trial 46 finished with value: 0.9283145751760223 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.5, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:33,433] Trial 47 finished with value: 0.9312713992239215 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:33,855] Trial 48 finished with value: 0.9330483029866732 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.425, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:34,250] Trial 49 finished with value: 0.9223903920776781 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.78, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:34,641] Trial 50 finished with value: 0.9081804294769371 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45999999999999996, 'subsample': 0.72, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:35,032] Trial 51 finished with value: 0.9336452864642775 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:35,413] Trial 52 finished with value: 0.9336452864642775 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:35,741] Trial 53 finished with value: 0.8862500658437659 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.65, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 11 with value: 0.9348287184169404.
# [I 2025-07-24 00:20:36,116] Trial 54 finished with value: 0.9300897231050165 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.42, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial
and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:45,136] Trial 78 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:45,549] Trial 79 finished with value: 0.9300897231050165 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:45,956] Trial 80 finished with value: 0.9342370024406088 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:46,341] Trial 81 finished with value: 0.9348287184169404 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:46,733] Trial 82 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:47,109] Trial 83 finished with value: 0.9348287184169404 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:47,486] Trial 84 finished with value: 0.9336417747967622 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:47,863] Trial 85 finished with value: 0.9324600986778572 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.385, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:48,246] Trial 86 finished with value: 0.9312749108914368 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:48,587] Trial 87 finished with value: 0.8986954155180588 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.67, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:48,974] Trial 88 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:49,350] Trial 89 finished with value: 0.928311063508507 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:49,730] Trial 90 finished with value: 0.9336417747967622 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:50,118] Trial 91 finished with value: 0.9348287184169404 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:50,505] Trial 92 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 75 with value: 0.9354221902270293.
# [I 2025-07-24 00:20:50,912] Trial 93 finished with value: 0.9360139062033607 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:51,295] Trial 94 finished with value: 0.9342370024406088 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:51,736] Trial 95 finished with value: 0.9360139062033607 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:52,183] Trial 96 finished with value: 0.9330500588204309 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:52,567] Trial 97 finished with value: 0.9354169227257563 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:52,944] Trial 98 finished with value: 0.9312713992239215 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:20:53,322] Trial 99 finished with value: 0.9342370024406088 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial
and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:26,589] Trial 184 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:26,974] Trial 185 finished with value: 0.9348304742506979 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:27,348] Trial 186 finished with value: 0.9330500588204309 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:27,722] Trial 187 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:28,106] Trial 188 finished with value: 0.9312749108914368 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:28,479] Trial 189 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:28,862] Trial 190 finished with value: 0.9318666268677681 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:29,244] Trial 191 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:29,641] Trial 192 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:30,032] Trial 193 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:30,415] Trial 194 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:30,803] Trial 195 finished with value: 0.9330518146541884 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:31,183] Trial 196 finished with value: 0.9330500588204309 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:31,564] Trial 197 finished with value: 0.9354169227257563 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:31,941] Trial 198 finished with value: 0.9312749108914368 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# [I 2025-07-24 00:21:32,326] Trial 199 finished with value: 0.9354221902270293 and parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}. Best is trial 93 with value: 0.9360139062033607.
# Best parameters: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt'}
# Best accuracy: 0.9360

# %%
# Evaluate top models
top_results = evaluate_top_models(study, X_train_selected, y_train, X_test_selected, y_test, top_n=500)

# Create comparison DataFrame
comparison_df = pd.DataFrame([
    {
        'Rank': r['Rank'],
        'CV_Accuracy': r['CV_Accuracy'],
        'Train_Accuracy': r['Train_Accuracy'], 
        'Test_Accuracy': r['Test_Accuracy'],
        'Overfitting': r['Train_Accuracy'] - r['Test_Accuracy']
    }
    for r in top_results
])
# Out:
# 🧪 EVALUATING TOP 500 MODELS ON TEST SET:
# ================================================================================
#
# #1 - CV: 0.9360 | Train: 0.9899 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #2 - CV: 0.9360 | Train: 0.9899 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #3 - CV: 0.9354 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #4 - CV: 0.9354 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #5 - CV: 0.9354 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
#
 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #49 - CV: 0.9354 | Train: 0.9905 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #50 - CV: 0.9354 | Train: 0.9905 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #51 - CV: 0.9354 | Train: 0.9905 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #52 - CV: 0.9348 | Train: 0.9882 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #53 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #54 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #55 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #56 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #57 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #58 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #59 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #60 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #61 - CV: 0.9348 | Train: 0.9893 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #62 - CV: 0.9342 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #63 - CV: 0.9342 | Train: 0.9882 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #64 - CV: 0.9342 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #65 - CV: 0.9342 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #66 - CV: 0.9342 | Train: 0.9887 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #67 - CV: 0.9342 | Train: 0.9887 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #68 - CV: 0.9342 | Train: 0.9882 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #69 - CV: 0.9342 | Train: 0.9882 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #70 - CV: 0.9342 | Train: 0.9893 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #71 - CV: 0.9342 | Train: 0.9882 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #72 - CV: 0.9336 | Train: 0.9870 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #73 - CV: 0.9336 | Train: 0.9870 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #74 - CV: 0.9336 | Train: 0.9870 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #75 - CV: 0.9336 | Train: 0.9870 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.41, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #76 - CV: 0.9336 | Train: 0.9870 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.415, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #77 - CV: 0.9336 | Train: 0.9870 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.415, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #78 - CV: 0.9336 | Train: 0.9870 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #79 - CV: 0.9336 | Train: 0.9882 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #80 - CV: 0.9336 | Train: 0.9882 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #81 - CV: 0.9336 | Train: 0.9882 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #82 - CV: 0.9336 | Train: 0.9882 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #83 - CV: 0.9336 | Train: 0.9870 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
#
 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #123 - CV: 0.9325 | Train: 0.9864 | Test: 0.9362
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.385, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #124 - CV: 0.9319 | Train: 0.9882 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.445, 'subsample': 0.85, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #125 - CV: 0.9319 | Train: 0.9882 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.425, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #126 - CV: 0.9319 | Train: 0.9882 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #127 - CV: 0.9319 | Train: 0.9887 | Test: 0.9456
# ...
#
# #160 - CV: 0.9289 | Train: 0.9858 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #161 - CV: 0.9283 | Train: 0.9870 | Test: 0.9385
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.8300000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #162 - CV: 0.9283 | Train: 0.9882 | Test: 0.9504
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.5, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #163 - CV: 0.9283 | Train: 0.9876 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #164 - CV: 0.9283 | Train: 0.9876 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #165 - CV: 0.9283 | Train: 0.9882 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.495, 'subsample': 0.8400000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #166 - CV: 0.9277 | Train: 0.9858 | Test: 0.9362
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #167 - CV: 0.9277 | Train: 0.9852 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.44999999999999996, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #168 - CV: 0.9271 | Train: 0.9864 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.8, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #169 - CV: 0.9265 | Train: 0.9870 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #170 - CV: 0.9259 | Train: 0.9864 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #171 - CV: 0.9259 | Train: 0.9864 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #172 - CV: 0.9259 | Train: 0.9858 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.485, 'subsample': 0.8200000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #173 - CV: 0.9254 | Train: 0.9876 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.81, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #174 - CV: 0.9248 | Train: 0.9852 | Test: 0.9504
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39999999999999997, 'subsample': 0.8, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #175 - CV: 0.9248 | Train: 0.9852 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.43, 'subsample': 0.8, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #176 - CV: 0.9230 | Train: 0.9805 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.77, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #177 - CV: 0.9224 | Train: 0.9840 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.395, 'subsample': 0.78, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #178 - CV: 0.9224 | Train: 0.9828 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.77, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #179 - CV: 0.9224 | Train: 0.9822 | Test: 0.9504
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.445, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #180 - CV: 0.9212 | Train: 0.9846 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #181 - CV: 0.9212 | Train: 0.9840 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.365, 'subsample': 0.77, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #182 - CV: 0.9206 | Train: 0.9828 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.78, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #183 - CV: 0.9206 | Train: 0.9828 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.76, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #184 - CV: 0.9194 | Train: 0.9846 | Test: 0.9504
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.79, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #185 - CV: 0.9182 | Train: 0.9828 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.40499999999999997, 'subsample': 0.76, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #186 - CV: 0.9141 | Train: 0.9787 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.37, 'subsample': 0.73, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #187 - CV: 0.9129 | Train: 0.9822 | Test: 0.9480
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.385, 'subsample': 0.75, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #188 - CV: 0.9123 | Train: 0.9781 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.39, 'subsample': 0.71, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #189 - CV: 0.9123 | Train: 0.9793 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.42, 'subsample': 0.73, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #190 - CV: 0.9117 | Train: 0.9799 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45499999999999996, 'subsample': 0.74, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #191 - CV: 0.9105 | Train: 0.9763 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.47, 'subsample': 0.73, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #192 - CV: 0.9082 | Train: 0.9763 | Test: 0.9456
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45999999999999996, 'subsample': 0.72, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #193 - CV: 0.9070 | Train: 0.9739 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.36, 'subsample': 0.7000000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #194 - CV: 0.9058 | Train: 0.9751 | Test: 0.9433
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.5, 'subsample': 0.7000000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #195 - CV: 0.9023 | Train: 0.9716 | Test: 0.9409
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.375, 'subsample': 0.6900000000000001, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #196 - CV: 0.8993 | Train: 0.9692 | Test: 0.9338
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.49, 'subsample': 0.68, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #197 - CV: 0.8987 | Train: 0.9692 | Test: 0.9385
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.38, 'subsample': 0.67, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #198 - CV: 0.8940 | Train: 0.9698 | Test: 0.9314
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.45999999999999996, 'subsample': 0.67, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #199 - CV: 0.8916 | Train: 0.9680 | Test: 0.9338
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.42, 'subsample': 0.66, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}
#
# #200 - CV: 0.8863 | Train: 0.9639 | Test: 0.9291
#    Key params: {'n_estimators': 170, 'learning_rate': 0.079, 'num_leaves': 5, 'max_depth': 6, 'min_child_samples': 255, 'reg_alpha': 0.435, 'subsample': 0.65, 'subsample_freq': 1, 'boosting_type': 'gbdt', 'verbosity': -1, 'random_state': 42, 'objective': 'multiclass', 'num_class': 7, 'gpu_device_id': 0, 'gpu_platform_id': 0}

# %%
comparison_df_sorted = comparison_df[comparison_df['Train_Accuracy'] != 1.0].copy()
comparison_df_sorted = comparison_df_sorted[comparison_df_sorted['Test_Accuracy'] >= 0.93].copy()
comparison_df_sorted = comparison_df_sorted[comparison_df_sorted['Overfitting'] < 0.05].copy()
comparison_df_sorted = comparison_df_sorted.sort_values(['Overfitting', 'Test_Accuracy'], 
                                                       ascending=[True, False])

print("\n📈 MODEL COMPARISON:")
display(comparison_df_sorted.round(4))
# Out:
# 📈 MODEL COMPARISON:
#      Rank  CV_Accuracy  Train_Accuracy  Test_Accuracy  Overfitting
# 196   197       0.8987          0.9692         0.9385       0.0307
# 194   195       0.9023          0.9716         0.9409       0.0307
# 192   193       0.9070          0.9739         0.9433       0.0307
# 191   192       0.9082          0.9763         0.9456       0.0307
# 193   194       0.9058          0.9751         0.9433       0.0319
# ..    ...          ...             ...            ...          ...
# 46     47       0.9354          0.9905         0.9409       0.0496
# 47     48       0.9354          0.9905         0.9409       0.0496
# 48     49       0.9354          0.9905         0.9409       0.0496
# 49     50       0.9354          0.9905         0.9409       0.0496
# 50     51       0.9354          0.9905         0.9409       0.0496
#
# [198 rows x 5 columns]
